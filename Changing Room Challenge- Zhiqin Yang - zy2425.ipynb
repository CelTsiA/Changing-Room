# %% [markdown]
# Zhiqin Yang zy2425

# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup


url = "https://www.thereformation.com/clothing?page=100" # the total pages won't be more than 100, so set page = 100 includes all the products
response = requests.get(url)
results_page = BeautifulSoup(response.content,'lxml') 
home = "https://www.thereformation.com/"

# %%
wholepage = results_page.find_all('div', {'class':"product-tile product-tile--default"}) #contains a brief introduction of the products

# %%
name = []
price = []
category = []
color = []
surl = []
img = []
for i in wholepage:
    item = i.get("data-aggregate")
    if item == '{"trackObject": {"ecommerce":{"click":{"products":[{"id":"1303674","name":"Patagonia Men':
        break # because we set page = 100 which is too big, so we stop when the contents includes an error. 
    item = eval(item)
    name.append(item['trackObject']['ecommerce']['click']['products'][0]['name'])
    price.append(item['trackObject']['ecommerce']['click']['products'][0]['price'])
    category.append(item['trackObject']['ecommerce']['click']['products'][0]['category'])
    color.append(item['trackObject']['ecommerce']['click']['products'][0]['dimension1'])#color
    href = home+i.find('a',{'class':"product-tile__anchor"}).get('href')#link
    surl.append(href)
    img.append(i.find('img').get('data-src'))#img

# %%
size = []
for i in surl: 
    suburl = i
    response = requests.get(suburl)
    sub = BeautifulSoup(response.content,'lxml') 
    search = sub.find_all('div',{'class':"product-attribute__contents flex flex-flow-wrap"})
    if len(search) > 1:
        sizes = search[1].get_text()[1:-1].replace('\n','-')#[1:-1] -> we delete the unexpected '\n'
    else:
        sizes = " "
    size.append(sizes)

# %%
des = []
for i in surl: 
    suburl = i
    response = requests.get(suburl)
    sub = BeautifulSoup(response.content,'lxml') 
    search = sub.find_all('div',{'class':"cms-generic-copy"})
    if len(search) > 1:
        subdes = search[1].get_text()[1:-1]
    else:
        subdes = ' '
    des.append(subdes)

# %%
material = []
for i in surl: 
    suburl = i
    response = requests.get(suburl)
    sub = BeautifulSoup(response.content,'lxml') 
    search = sub.find_all('div',{'class':"margin-b--15"})
    if len(search) > 3:
        fabric = search[3].get_text()[1:-1]
    else:
        fabric = ' '
    material.append(fabric)

# %%
material
# Out:
# ['This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Dry clean only',
#  'Wash cold + line dry',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Wash cold + dry flat',
#  'Dry clean only',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  ' ',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL ® lyocell, 12% spandex.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight woven suiting fabric - 100% TENCEL™ Lyocell.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Wash cold + line dry',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight woven suiting fabric - 100% TENCEL™ Lyocell.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a deadstock trench fabric made with 63% Cotton, 37% Polyester.',
#  ' ',
#  'Wash cold + line dry',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a medium weight non-stretch denim - 60% Organically Grown Cotton /40% TENCEL™ Lyocell.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight woven suiting fabric - 100% TENCEL™ Lyocell.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'Wash cold + line dry',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a medium weight non-stretch denim - 60% Organically Grown Cotton /40% TENCEL™ Lyocell.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight woven suiting fabric - 100% TENCEL™ Lyocell.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Cotton Cinch is a lighter weight stretch fabric with a soft handfeel made with 88% organic cotton, 12% spandex.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Wash cold + line dry',
#  ' ',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  ' ',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'Hand wash + dry flat',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL ® lyocell, 12% spandex.',
#  'Hand wash + dry flat',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Pointelle is a light weight, stretchy ribbed knit with a soft handfeel - 98% Organic Cotton, 2% spandex.',
#  'Wash cold + line dry',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'Pointelle is a light weight, stretchy ribbed knit with a soft handfeel - 98% Organic Cotton, 2% spandex.',
#  'Wash cold + line dry',
#  'Cotton Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 45% TENCEL™ Lyocell, 45% Organic Cotton, 10% Spandex.',
#  ' ',
#  'Cotton Cinch is a lighter weight stretch fabric with a soft handfeel made with 88% organic cotton, 12% spandex.',
#  'This is a lightweight woven suiting fabric - 100% TENCEL™ Lyocell.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Wash cold + line dry',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL™ lyocell, 12% spandex.',
#  'Wash cold + line dry',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  ' ',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  ' ',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Wash cold + line dry',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'Cotton Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 45% TENCEL™ Lyocell, 45% Organic Cotton, 10% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a medium weight rigid fleece fabric - 100% Organic cotton.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'Dry clean only',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'Dry clean only',
#  'Dry clean only',
#  'Wide Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL ® lyocell, 12% spandex.',
#  'Cotton Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 45% TENCEL™ Lyocell, 45% Organic Cotton, 10% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Dry clean only',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'Dry clean only',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  ' ',
#  'Dry clean only',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'Cotton Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 45% TENCEL™ Lyocell, 45% Organic Cotton, 10% Spandex.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL ® lyocell, 12% spandex.',
#  'Wash cold + line dry',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight woven suiting fabric - 100% TENCEL™ Lyocell.',
#  'Wash cold + line dry',
#  'Wash cold + line dry',
#  ' ',
#  'Cotton Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 45% TENCEL™ Lyocell, 45% Organic Cotton, 10% Spandex.',
#  ' ',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Wash cold + line dry',
#  'Cotton Cinch is a lighter weight stretch fabric with a soft handfeel made with 88% organic cotton, 12% spandex.',
#  'Cotton Cinch is a lighter weight stretch fabric with a soft handfeel made with 88% organic cotton, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'This is a lightweight woven suiting fabric - 100% TENCEL™ Lyocell.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  ' ',
#  'This is a denim fabric made with 100% Regenerative Cotton.',
#  'This is a medium weight rigid fleece fabric - 100% Organic cotton.',
#  'Cotton Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 45% TENCEL™ Lyocell, 45% Organic Cotton, 10% Spandex.',
#  'Dry clean only',
#  'This is a rigid denim that was sustainably made with 60% Organically Grown Cotton, 40% TENCEL™ Lyocell.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Wash cold + line dry',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Hand wash + dry flat',
#  'Wash cold + line dry',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL ® lyocell, 12% spandex.',
#  ' ',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Wash cold / tumble dry low',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Wash cold + line dry',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  ' ',
#  'Cotton Cinch is a lighter weight stretch fabric with a soft handfeel made with 88% organic cotton, 12% spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  ' ',
#  ' ',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'Dry clean only',
#  'Dry clean only',
#  'Dry clean only',
#  'Dry clean only',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lyocell-linen sweater blend made with 70% TENCEL™ and 30% Linen.',
#  'Wide Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL ® lyocell, 12% spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  ' ',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a medium weight rigid fleece fabric - 100% Organic cotton.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a medium weight non-stretch denim - 60% Organically Grown Cotton /40% TENCEL™ Lyocell.',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'This is a denim fabric made with 100% Regenerative Cotton.',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a rigid denim that was sustainably made with 60% Organically Grown Cotton, 40% TENCEL™ Lyocell.',
#  'This is a medium weight non-stretch denim - 60% Organically Grown Cotton /40% TENCEL™ Lyocell.',
#  'This is a medium weight stretch knit ponte fabric - 97% Micro modal / 3% Spandex.',
#  'Wash cold + line dry',
#  'This is a medium weight non-stretch denim - 60% Organically Grown Cotton /40% TENCEL™ Lyocell.',
#  'Dry clean only',
#  'Dry clean only',
#  ' ',
#  'Wash cold / tumble dry low',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  ' ',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'Dry clean only',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  ' ',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Hand wash + dry flat',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'Wash cold + dry flat',
#  'Dry clean only',
#  'Hand wash + dry flat',
#  'Cotton Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 45% TENCEL™ Lyocell, 45% Organic Cotton, 10% Spandex.',
#  'Dry clean only',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'Wash cold + line dry',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Hand wash + dry flat',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Spot clean',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Wash cold + line dry',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Wash cold + line dry',
#  'Hand wash + dry flat',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a rigid denim that was sustainably made with 60% Organically Grown Cotton, 40% TENCEL™ Lyocell.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Light weight dead-stock mesh with stretch',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Dry clean only',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  'This is a deadstock lightweight eyelet woven fabric made with 100% Cotton Deadstock.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  'This is a denim fabric made with 100% Regenerative Cotton.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'Light weight dead-stock mesh with stretch',
#  'Wash cold + line dry',
#  'Dry clean only',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  ' ',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Wash cold + line dry',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a deadstock lightweight eyelet woven fabric.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Hand wash + dry flat',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a deadstock lightweight eyelet woven fabric.',
#  'Wash cold + line dry',
#  ' ',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'Hand wash + dry flat',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a medium weight stretch knit ponte fabric - 97% Micro modal / 3% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'Spot clean',
#  'Wash cold + line dry',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a soft, lightweight jersey knit - 100% TENCEL ® Lyocell - Refibra.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL ® lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Dry clean only',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a denim fabric made with 100% Regenerative Cotton.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a denim fabric made with 100% Regenerative Cotton.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Dry clean only',
#  ' ',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  ' ',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'This is a deadstock lightweight eyelet woven fabric made with 100% Cotton Deadstock.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Wash cold / tumble dry low',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  ' ',
#  'This is a lightweight linen fabric - 100% linen.',
#  ' ',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Dry clean only',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a medium weight non-stretch denim - 60% Organically Grown Cotton /40% TENCEL™ Lyocell.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Wash cold + line dry',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  ' ',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  ' ',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  ' ',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  ' ',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  ' ',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  ' ',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Hand wash + dry flat',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Hand wash + dry flat',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Hand wash + dry flat',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Dry clean only',
#  'Dry clean only',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight woven suiting fabric - 100% TENCEL™ Lyocell.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  ' ',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lyocell-linen sweater blend made with 70% TENCEL™ and 30% Linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  ' ',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Upper is made from soft foil metallic leather with high shine and subtle surface texture.',
#  'Upper is made from soft foil metallic leather with high shine and subtle surface texture.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight woven suiting fabric - 100% TENCEL™ Lyocell.',
#  ' ',
#  'This is a lightweight woven suiting fabric - 100% TENCEL™ Lyocell.',
#  'Cotton Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 45% TENCEL™ Lyocell, 45% Organic Cotton, 10% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'Hand wash + dry flat',
#  'Hand wash + dry flat',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a denim fabric made with 100% Regenerative Cotton.',
#  'Wash cold + line dry',
#  'This is a denim fabric made with 100% Regenerative Cotton.',
#  'This is a denim fabric made with 100% Regenerative Cotton.',
#  'Cotton Cinch is a lighter weight stretch fabric with a soft handfeel made with 88% organic cotton, 12% spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Wash cold + line dry',
#  'Wash cold / tumble dry low',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Wash cold / tumble dry low',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Wash cold / tumble dry low',
#  'Cotton Cinch is a lighter weight stretch fabric with a soft handfeel made with 88% organic cotton, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Wash cold + line dry',
#  'This is a denim fabric made with 100% Regenerative Cotton.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  ' ',
#  'This is a lightweight woven suiting fabric - 100% TENCEL™ Lyocell.',
#  'Wash cold / tumble dry low',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Cotton Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 45% TENCEL™ Lyocell, 45% Organic Cotton, 10% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Wide Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL ® lyocell, 12% spandex.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL ® lyocell, 12% spandex.',
#  'Wash cold + line dry',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  'This is a medium weight rigid fleece fabric - 100% Organic cotton.',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  'Wash cold + line dry',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a denim fabric made with 100% Regenerative Cotton.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'Dry clean only',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
# ...
#  'Wash cold + line dry',
#  'Wash cold + line dry',
#  'Wash cold + line dry',
#  'Wash cold + line dry',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a medium weight non-stretch denim - 60% Organically Grown Cotton /40% TENCEL™ Lyocell.',
#  'This is a lightweight linen fabric - 100% linen.',
#  ' ',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Hand wash + dry flat',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL™ lyocell, 12% spandex.',
#  'Dry clean only',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  ' ',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Wash cold + line dry',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a medium weight rigid fleece fabric - 100% Organic cotton.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a medium weight rigid fleece fabric - 100% Organic cotton.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Hand wash + dry flat',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'Cotton Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 45% TENCEL™ Lyocell, 45% Organic Cotton, 10% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Hand wash + dry flat',
#  ' ',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'Cotton Cinch is a lighter weight stretch fabric with a soft handfeel made with 88% organic cotton, 12% spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'Dry clean only',
#  ' ',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  ' ',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Sweater Rib is a medium weight, stretchy sweater ribbed knit with a soft handfeel - 95% TENCEL™ Modal, 5% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a rigid denim that was sustainably made with 60% Organically Grown Cotton, 40% TENCEL™ Lyocell.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a medium weight rigid fleece fabric - 100% Organic cotton.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'Dry clean only',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Hand wash + dry flat',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'Dry clean only',
#  'Hand wash + dry flat',
#  'This is a medium weight cotton sweater knit - 100% organically grown cotton.',
#  'This is a soft, lightweight jersey knit - 100% Organic Cotton.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a soft, lightweight jersey knit - 100% Organic Cotton.',
#  'This is a rigid denim that was sustainably made with 60% Organically Grown Cotton, 40% TENCEL™ Lyocell.',
#  'Dry clean only',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'Dry clean only',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Hand wash + dry flat',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  'This is a medium weight stretch knit ponte fabric - 97% Micro modal / 3% Spandex.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL ® lyocell, 12% spandex.',
#  'Bovine leather with lustrous patent finish.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'This is a medium weight rigid fleece fabric - 100% Organic cotton.',
#  'Wide Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL ® lyocell, 12% spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Upper is made from printed leather with a soft hand and subtle surface texture.',
#  ' ',
#  'Bovine leather with lustrous patent finish.',
#  ' ',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  ' ',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'Wash cold + line dry',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Hand wash + dry flat',
#  'Dry clean only',
#  'Light weight dead-stock mesh with stretch',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'This is a medium weight rigid fleece fabric - 100% Organic cotton.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a medium weight rigid fleece fabric - 100% Organic cotton.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a medium weight cotton sweater knit - 100% Organically Grown Cotton.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Dry clean only',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'Hand wash + dry flat',
#  ' ',
#  'Hand wash + dry flat',
#  'Pointelle is a light weight, stretchy ribbed knit with a soft handfeel - 98% Organic Cotton, 2% spandex.',
#  ' ',
#  'This is a lightweight linen fabric - 100% linen.',
#  ' ',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  'Bovine leather with lustrous patent finish.',
#  'Wash cold + dry flat',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  ' ',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Wash cold + line dry',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Cotton Cinch is a lighter weight stretch fabric with a soft handfeel made with 88% organic cotton, 12% spandex.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'Dry clean only',
#  'Wash cold + line dry',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Wash cold + line dry',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% viscose.',
#  'Eco Rib is a medium weight, stretchy ribbed knit with a soft handfeel - 88% TENCEL™ lyocell, 12% spandex.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight linen fabric - 100% linen.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  'This is a lightweight drapey crepe fabric with a dry hand feel - 53% viscose, 47% rayon.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL™ lyocell, 12% spandex.',
#  'Upper is made from glove leather with a soft hand and subtle surface texture.',
#  'This is a stretch poplin fabric made with 98% Organically Grown Cotton, 2% Spandex.',
#  'Eco Cinch is a light weight, soft, stretch jersey fabric - 88% TENCEL ® lyocell, 12% spandex.',
#  'Upper is made from box calf a heritage leather that is quite firm but will soften over time.',
#  'This is a lightweight georgette fabric with a dry handfeel - 100% Viscose.',
#  ...]

# %%
import pandas as pd
scrap_result = pd.DataFrame(name,columns = ["Product Name"])

# %%
scrap_result["Price"] = price
scrap_result["Category"] = category
scrap_result["Color"] = color
scrap_result["Size"] = size
scrap_result["Material"] = material
scrap_result["Description"] = des
scrap_result["Link"] = surl
scrap_result["Img Link"] = img #form the table we want

# %%
from datetime import datetime
now = datetime.now().time()
timenow = [now.strftime("%Y-%m-%d %H:%M:%S")]
scrap_result["Scrapped Date"] = timenow * len(name)# show the date we scrap these information
# because reformation only sells clothing for women, so I didn't include the "gender" and "secondhand" in the table

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.3-cp39-cp39-win_amd64.whl (1.2 MB)
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.3

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres@localhost:5432/Reformation')
scrap_result.to_sql('scrap_result',engine,index=False,if_exists='append')
# the codes we need to update our data into AWS RDS is similar
